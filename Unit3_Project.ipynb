# %% [markdown]
# <a href="https://colab.research.google.com/github/devina-li/Unit_2_Python/blob/main/Unit3_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

us = pd.read_csv('https://raw.githubusercontent.com/nytimes/covid-19-data/master/us-counties.csv')
us
# Out:
#               date      county       state     fips  cases  deaths
# 0       2020-01-21   Snohomish  Washington  53061.0      1     0.0
# 1       2020-01-22   Snohomish  Washington  53061.0      1     0.0
# 2       2020-01-23   Snohomish  Washington  53061.0      1     0.0
# 3       2020-01-24        Cook    Illinois  17031.0      1     0.0
# 4       2020-01-24   Snohomish  Washington  53061.0      1     0.0
# ...            ...         ...         ...      ...    ...     ...
# 943228  2021-01-18  Sweetwater     Wyoming  56037.0   3312    26.0
# 943229  2021-01-18       Teton     Wyoming  56039.0   2753     4.0
# 943230  2021-01-18       Uinta     Wyoming  56041.0   1833     9.0
# 943231  2021-01-18    Washakie     Wyoming  56043.0    843    23.0
# 943232  2021-01-18      Weston     Wyoming  56045.0    602     4.0
#
# [943233 rows x 6 columns]

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

us = pd.read_csv('https://raw.githubusercontent.com/nytimes/covid-19-data/master/us-counties.csv')
us.describe()
# Out:
#                 fips         cases         deaths
# count  934434.000000  9.432330e+05  923068.000000
# mean    31273.607788  2.256154e+03      57.562226
# std     16301.113750  1.185291e+04     462.654322
# min      1001.000000  0.000000e+00       0.000000
# 25%     19001.000000  4.100000e+01       0.000000
# 50%     29217.000000  2.690000e+02       5.000000
# 75%     46101.000000  1.161000e+03      25.000000
# max     78030.000000  1.024592e+06   26104.000000

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

us = pd.read_csv('https://raw.githubusercontent.com/nytimes/covid-19-data/master/us-counties.csv')
us.columns
# Out:
# Index(['date', 'county', 'state', 'fips', 'cases', 'deaths'], dtype='object')

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

us = pd.read_csv('https://raw.githubusercontent.com/nytimes/covid-19-data/master/us-counties.csv')

us.groupby(['state'])['cases'].count()
# Out:
# state
# Alabama                     20152
# Alaska                       7185
# Arizona                      4670
# Arkansas                    22552
# California                  17845
# Colorado                    18807
# Connecticut                  2771
# Delaware                     1211
# District of Columbia          318
# Florida                     20722
# Georgia                     48089
# Guam                          310
# Hawaii                       1318
# Idaho                       12062
# Illinois                    30073
# Indiana                     27726
# Iowa                        29070
# Kansas                      28769
# Kentucky                    34972
# Louisiana                   19703
# Maine                        5072
# Maryland                     7645
# Massachusetts                4714
# Michigan                    24882
# Minnesota                   25643
# Mississippi                 24730
# Missouri                    33439
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

us = pd.read_csv('https://raw.githubusercontent.com/nytimes/covid-19-data/master/us-counties.csv')
us.columns

us_state = us[us['state']=='New York']
us_state
# Out:
#               date         county     state     fips  cases  deaths
# 416     2020-03-01  New York City  New York      NaN      1     0.0
# 448     2020-03-02  New York City  New York      NaN      1     0.0
# 482     2020-03-03  New York City  New York      NaN      2     0.0
# 518     2020-03-04  New York City  New York      NaN      2     0.0
# 519     2020-03-04    Westchester  New York  36119.0      9     0.0
# ...            ...            ...       ...      ...    ...     ...
# 941886  2021-01-18     Washington  New York  36115.0   1473    24.0
# 941887  2021-01-18          Wayne  New York  36117.0   3646    51.0
# 941888  2021-01-18    Westchester  New York  36119.0  84419  1797.0
# 941889  2021-01-18        Wyoming  New York  36121.0   2135    42.0
# 941890  2021-01-18          Yates  New York  36123.0    813    16.0
#
# [17852 rows x 6 columns]

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

us = pd.read_csv('https://raw.githubusercontent.com/nytimes/covid-19-data/master/us-counties.csv')

us_county = us.query('state == "New York" and county == "New York City"')

us_county = pd.read_csv('CovidData.csv')
us_county['New cases'] = us_county['cases'] - us_county['cases'].shift(1)
us_county['New deaths'] = us_county['deaths'] - us_county['deaths'].shift(1)
us_county = us_county.drop([
    "fips"],
    axis=1)
us_county.tail(30)
# Out:
#            date         county     state  ...   deaths  New cases  New deaths
# 294  2020-12-20  New York City  New York  ...  24697.0     2741.0        20.0
# 295  2020-12-21  New York City  New York  ...  24735.0     3787.0        38.0
# 296  2020-12-22  New York City  New York  ...  24768.0     4039.0        33.0
# 297  2020-12-23  New York City  New York  ...  24790.0     4176.0        22.0
# 298  2020-12-24  New York City  New York  ...  24842.0     5441.0        52.0
# 299  2020-12-25  New York City  New York  ...  24889.0     4606.0        47.0
# 300  2020-12-26  New York City  New York  ...  24931.0     4191.0        42.0
# 301  2020-12-27  New York City  New York  ...  24973.0     3424.0        42.0
# 302  2020-12-28  New York City  New York  ...  25008.0     3450.0        35.0
# 303  2020-12-29  New York City  New York  ...  25055.0     5152.0        47.0
# 304  2020-12-30  New York City  New York  ...  25099.0     4205.0        44.0
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

us = pd.read_csv('https://raw.githubusercontent.com/nytimes/covid-19-data/master/us-counties.csv')

us_county = us[(us['date'] >= '2020-12-20') & (us['date'] <= '2021-01-18')]
us_county30 = us_county[us_county['county'] == 'New York City']
us_county30.describe()
# Out:
#        fips          cases        deaths
# count   0.0      30.000000     30.000000
# mean    NaN  453535.766667  25313.000000
# std     NaN   46566.528601    414.671287
# min     NaN  383808.000000  24697.000000
# 25%     NaN  414334.500000  24981.750000
# 50%     NaN  448778.500000  25264.000000
# 75%     NaN  491867.250000  25616.750000
# max     NaN  536287.000000  26104.000000

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

us = pd.read_csv('https://raw.githubusercontent.com/nytimes/covid-19-data/master/us-counties.csv')

us_county = us.query('state == "New York" and county == "New York City"')

us_county = us[(us['date'] >= '2020-12-20') & (us['date'] <= '2021-01-18')]
us_county30 = us_county[us_county['county'] == 'New York City']

us_county30.plot(kind = 'line', x = 'date', y = 'deaths')

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

us = pd.read_csv('https://raw.githubusercontent.com/nytimes/covid-19-data/master/us-counties.csv')

us_county = us[(us['date'] >= '2020-12-20') & (us['date'] <= '2021-01-18')]
us_county30 = us_county[us_county['county'] == 'New York City']

us_county30.plot(kind = 'line', x = 'date', y = 'cases')

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

us = pd.read_csv('https://raw.githubusercontent.com/nytimes/covid-19-data/master/us-counties.csv')

us_county = us[(us['date'] >= '2020-12-20') & (us['date'] <= '2021-01-18')]
us_county30 = us_county[us_county['county'] == 'New York City']

us_county30.plot(kind = 'line', x = 'cases', y = 'deaths')

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

us = pd.read_csv('https://raw.githubusercontent.com/nytimes/covid-19-data/master/us-counties.csv')

states = ['New York', 'California', 'Texas', 'Washington']

for s in states:
  us_ = us.query(f"state == '{s}'").reset_index()
  plt.plot(us_['date'], us_['cases'], label=s)
  plt.plot()

plt.title('States and Total Cases')
plt.xlabel('Date')
plt.ylabel('Cases')
plt.legend()
plt.show()

for s in states:
  us_ = us.query(f"state == '{s}'").reset_index()
  plt.plot(us_['date'], us_['deaths'], label=s)
  plt.plot()

plt.title('States and Total Deaths')
plt.xlabel('Date')
plt.ylabel('Deaths')
plt.legend()
plt.show()

# %% [markdown]
# As of 2021-01-18 there has been a total of 536,287 cases and 26,104 deaths related to Covid-19 in New York City, New York. Observing data from a 30 day period from 2020-12-20 to 2021-01-18, there has been a steady increase in the amount of daily cases and deaths with no sign of the curve flattening.
#
# Comparing the data from 4 different states (New York, California, Texas, and Washington), New York had the most cases at the beginning of the pandemic and Washington had the least. However, newer data shows that California has the highest rate of infection compared to the other 4 states and Washington still has the least amount of cases.
#
# New York has the highest amount of death amongst the 4 states with California right behind. Texas has had a slight increase in the amount of death around the middle of the pandemic. Meanwhile, Washington has the least amount of death but the death rate is slowly increasing.
#
# In conclusion, Covid-19 cases and deaths have continued to rise since the beginning of the first recorded case and currently there is no sign of the curve flattening.
