# %% [markdown]
# <a href="https://colab.research.google.com/github/devina-li/Unit_2_Python/blob/main/Unit_3_Mini_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

us = pd.read_csv('https://raw.githubusercontent.com/nytimes/covid-19-data/master/us-counties.csv')
us
# Out:
#               date      county       state     fips  cases  deaths
# 0       2020-01-21   Snohomish  Washington  53061.0      1     0.0
# 1       2020-01-22   Snohomish  Washington  53061.0      1     0.0
# 2       2020-01-23   Snohomish  Washington  53061.0      1     0.0
# 3       2020-01-24        Cook    Illinois  17031.0      1     0.0
# 4       2020-01-24   Snohomish  Washington  53061.0      1     0.0
# ...            ...         ...         ...      ...    ...     ...
# 933493  2021-01-15  Sweetwater     Wyoming  56037.0   3262    26.0
# 933494  2021-01-15       Teton     Wyoming  56039.0   2605     4.0
# 933495  2021-01-15       Uinta     Wyoming  56041.0   1806     9.0
# 933496  2021-01-15    Washakie     Wyoming  56043.0    839    23.0
# 933497  2021-01-15      Weston     Wyoming  56045.0    602     4.0
#
# [933498 rows x 6 columns]

# %%
import pandas as pd
import numpy as np

us = pd.read_csv('https://raw.githubusercontent.com/nytimes/covid-19-data/master/us-counties.csv')
us.columns

us[(us['state'] == 'New York')]
# Out:
#               date         county     state     fips  cases  deaths
# 416     2020-03-01  New York City  New York      NaN      1     0.0
# 448     2020-03-02  New York City  New York      NaN      1     0.0
# 482     2020-03-03  New York City  New York      NaN      2     0.0
# 518     2020-03-04  New York City  New York      NaN      2     0.0
# 519     2020-03-04    Westchester  New York  36119.0      9     0.0
# ...            ...            ...       ...      ...    ...     ...
# 932151  2021-01-15     Washington  New York  36115.0   1381    21.0
# 932152  2021-01-15          Wayne  New York  36117.0   3527    50.0
# 932153  2021-01-15    Westchester  New York  36119.0  81981  1774.0
# 932154  2021-01-15        Wyoming  New York  36121.0   1987    41.0
# 932155  2021-01-15          Yates  New York  36123.0    758    16.0
#
# [17678 rows x 6 columns]

# %%
import pandas as pd
import numpy as np

us = pd.read_csv('https://raw.githubusercontent.com/nytimes/covid-19-data/master/us-counties.csv')

countylevel = county.query('state == "New York" and county == "New York City"')

countylevel.to_csv(r'CovidData.csv',index = False)
countylevel = pd.read_csv('CovidData.csv')
countylevel['New cases'] = countylevel['cases'] - countylevel['cases'].shift(1).fillna(0)
countylevel['New deaths'] = countylevel['deaths'] - countylevel['deaths'].shift(1).fillna(0)
countylevel.tail(30)

# why no data at all?
# Out:
# Empty DataFrame
# Columns: [date, county, state, cases, deaths, New cases, New deaths]
# Index: []

# %%
import pandas as pd
import numpy as np

us = pd.read_csv('https://raw.githubusercontent.com/nytimes/covid-19-data/master/us-counties.csv')

countylevel = county.query('state == "California" and county == "Orange"')

countylevel.to_csv(r'CovidData.csv',index = False)
countylevel = pd.read_csv('CovidData.csv')
countylevel['New cases'] = countylevel['cases'] - countylevel['cases'].shift(1).fillna(0)
countylevel['New deaths'] = countylevel['deaths'] - countylevel['deaths'].shift(1).fillna(0)
countylevel.tail(30)
# Out:
#            date  county       state   cases  deaths  New cases  New deaths
# 327  2020-12-17  Orange  California  116116  1731.0     2624.0        13.0
# 328  2020-12-18  Orange  California  118721  1734.0     2605.0         3.0
# 329  2020-12-19  Orange  California  122168  1760.0     3447.0        26.0
# 330  2020-12-20  Orange  California  126776  1775.0     4608.0        15.0
# 331  2020-12-21  Orange  California  130530  1777.0     3754.0         2.0
# 332  2020-12-22  Orange  California  132772  1779.0     2242.0         2.0
# 333  2020-12-23  Orange  California  137194  1781.0     4422.0         2.0
# 334  2020-12-24  Orange  California  140699  1782.0     3505.0         1.0
# 335  2020-12-25  Orange  California  141205  1782.0      506.0         0.0
# 336  2020-12-26  Orange  California  149439  1845.0     8234.0        63.0
# 337  2020-12-27  Orange  California  153527  1846.0     4088.0         1.0
# 338  2020-12-28  Orange  California  157926  1846.0     4399.0         0.0
# 339  2020-12-29  Orange  California  160476  1847.0     2550.0         1.0
# 340  2020-12-30  Orange  California  164990  1874.0     4514.0        27.0
# 341  2020-12-31  Orange  California  166196  1875.0     1206.0         1.0
# 342  2021-01-01  Orange  California  166196  1875.0        0.0         0.0
# 343  2021-01-02  Orange  California  170802  1901.0     4606.0        26.0
# 344  2021-01-03  Orange  California  170802  1901.0        0.0         0.0
# 345  2021-01-04  Orange  California  180386  1926.0     9584.0        25.0
# 346  2021-01-05  Orange  California  181850  1926.0     1464.0         0.0
# 347  2021-01-06  Orange  California  185125  1943.0     3275.0        17.0
# 348  2021-01-07  Orange  California  188013  1972.0     2888.0        29.0
# 349  2021-01-08  Orange  California  191804  1998.0     3791.0        26.0
# 350  2021-01-09  Orange  California  196024  2041.0     4220.0        43.0
# 351  2021-01-10  Orange  California  199401  2091.0     3377.0        50.0
# 352  2021-01-11  Orange  California  202787  2120.0     3386.0        29.0
# 353  2021-01-12  Orange  California  207318  2148.0     4531.0        28.0
# 354  2021-01-13  Orange  California  211331  2179.0     4013.0        31.0
# 355  2021-01-14  Orange  California  214649  2195.0     3318.0        16.0
# 356  2021-01-15  Orange  California  217925  2277.0     3276.0        82.0

# %%
import pandas as pd
import numpy as np

us = pd.read_csv('https://raw.githubusercontent.com/nytimes/covid-19-data/master/us-counties.csv')

countylevel = county.query('state == "California" and county == "Orange"')

countylevel.to_csv(r'CovidData.csv',index = False)
countylevel = pd.read_csv('CovidData.csv')
countylevel['New cases'] = countylevel['cases'] - countylevel['cases'].shift(1).fillna(0)
countylevel['New deaths'] = countylevel['deaths'] - countylevel['deaths'].shift(1).fillna(0)
countylevel.tail(30)

countylevel.plot(kind = 'line', x = 'date', y = 'New cases')
countylevel.plot()
